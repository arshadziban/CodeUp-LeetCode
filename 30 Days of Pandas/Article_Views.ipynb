# %%
import pandas as pd

# %%
data = [[1, 3, 5, '2019-08-01'], [1, 3, 6, '2019-08-02'], [2, 7, 7, '2019-08-01'], [2, 7, 6, '2019-08-02'], [4, 7, 1, '2019-07-22'], [3, 4, 4, '2019-07-21'], [3, 4, 4, '2019-07-21']]
views = pd.DataFrame(data, columns=['article_id', 'author_id', 'viewer_id', 'view_date']).astype({'article_id':'Int64', 'author_id':'Int64', 'viewer_id':'Int64', 'view_date':'datetime64[ns]'})

# %%
views
# Out:
#    article_id  author_id  viewer_id  view_date
# 0           1          3          5 2019-08-01
# 1           1          3          6 2019-08-02
# 2           2          7          7 2019-08-01
# 3           2          7          6 2019-08-02
# 4           4          7          1 2019-07-22
# 5           3          4          4 2019-07-21
# 6           3          4          4 2019-07-21

# %%
views=views.sort_values(by='author_id',ascending=True)

# %%
views
# Out:
#    article_id  author_id  viewer_id  view_date
# 0           1          3          5 2019-08-01
# 1           1          3          6 2019-08-02
# 6           3          4          4 2019-07-21
# 5           3          4          4 2019-07-21
# 3           2          7          6 2019-08-02
# 2           2          7          7 2019-08-01
# 4           4          7          1 2019-07-22

# %%
result = views[views.author_id == views.viewer_id][['author_id']].rename(columns={'author_id': 'id'}).drop_duplicates()

# %%
result
# Out:
#    id
# 6   4
# 2   7
